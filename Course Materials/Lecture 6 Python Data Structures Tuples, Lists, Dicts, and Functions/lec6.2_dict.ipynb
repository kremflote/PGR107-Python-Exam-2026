# %% [markdown]
# # KUC, PGR107, Lec6

# %% [markdown]
# # 1. Dict

# %% [markdown]
# ## 1.1 create, access, set, update

# %%
empty_dict = {}
d1 = {'a' : 'some value', 'b' : [1, 2, 3, 4]}
len(d1)
# Out:
# 2

# %%
d1['a']
# Out:
# 'some value'

# %%
print(d1['a'])
# Out:
# some value

# %%
d1[7] = 'an integer'
d1[7]
# Out:
# 'an integer'

# %%
print(d1)
# Out:
# {'a': 'some value', 'b': [1, 2, 3, 4], 7: 'an integer'}

# %%
'a' in d1
# Out:
# True

# %%
'some value' in d1
# Out:
# False

# %%
'7' in d1
# Out:
# False

# %%
7 in d1
# Out:
# True

# %%
d1[5] = 'some value'
d1
d1['dummy'] = 'another value'
d1
del d1[5]
d1
print(d1)
# Out:
# {'a': 'some value', 'b': [1, 2, 3, 4], 7: 'an integer', 'dummy': 'another value'}

# %%
# pop
ret = d1.pop('dummy')
ret
d1
# Out:
# {'a': 'some value', 'b': [1, 2, 3, 4], 7: 'an integer'}

# %%
# keys and values
print(len(d1))
print(d1.keys())

print(d1.values())
# Out:
# 3
# dict_keys(['a', 'b', 7])
# dict_values(['some value', [1, 2, 3, 4], 'an integer'])

# %%
list(d1.keys())
list(d1.values())
# Out:
# ['some value', [1, 2, 3, 4], 'an integer']

# %%
{}
d1.update({'b' : 'foo', 'c' : 12})
d1
# Out:
# {'a': 'some value', 'b': 'foo', 7: 'an integer', 'c': 12}

# %%
d = {'student_001':'Lukas','student_002':'Oscar'}
for i in d:
    value = d[i]
    print(value)
# Out:
# Lukas
# Oscar

# %%
print(d1)
print('the length of d1 is: ', len(d1))
print('we are going to insert an element, indexed by c')
d1['c'] = 'a new sample'
print('after operation, the new length is: ',len(d1))
# Out:
# {'a': 'some value', 'b': 'foo', 7: 'an integer', 'c': 12}
# the length of d1 is:  4
# we are going to insert an element, indexed by c
# after operation, the new length is:  4

# %%
for i in range(len(d1)):
    print(d1[i])

# %%
for i in d1:
    print(d1[i])
# Out:
# some value
# foo
# an integer
# a new sample

# %%
d1.items()

for key,value in d1.items():
    print('key and value are: ', key, value )
# Out:
# key and value are:  a some value
# key and value are:  b foo
# key and value are:  7 an integer
# key and value are:  c a new sample

# %%
for key,value in d.items():
    print(value)
    print(d[key])
    print(value == d[key])
# Out:
# Lukas
# Lukas
# True
# Oscar
# Oscar
# True

# %%
d.values()
v = d.values()
print(type(v))

# for i in range(len(v)):
#     v[i]
# Out:
# <class 'dict_values'>

# %% [markdown]
# ## 1.2 Build-in functions

# %%
seq1 = ['foo', 'bar', 'baz']
seq2 = ['one', 'two', 'three']
zipped = zip(seq1, seq2)
ls= list(zipped)
print(ls)
# Out:
# [('foo', 'one'), ('bar', 'two'), ('baz', 'three')]

# %%
print(type(zipped))
# Out:
# <class 'zip'>

# %%
for i, (a, b) in enumerate(ls): #zip(seq1, seq2)
    print(a)
    print(b)
    print('{0}: {1}, {2}'.format(i, a, b))
# Out:
# foo
# one
# 0: foo, one
# bar
# two
# 1: bar, two
# baz
# three
# 2: baz, three

# %% [markdown]
# ## 1.3 An example

# %%
words = ['apple', 'bat', 'bar', 'atom', 'book']
by_letter = {}
b1 = {}
print(type(b1))
for word in words:
    letter = word[0]
    if letter not in by_letter:
        by_letter[letter] = [word]
    else:
        by_letter[letter].append(word)
by_letter
# Out:
# <class 'dict'>
# {'a': ['apple', 'atom'], 'b': ['bat', 'bar', 'book']}

# %% [markdown]
# ## 1.4 name space

# %%
a = None
b=1
print('before calling the function:',a)


def bind_a_variable():
    global a
    b = [1]
    a = []
    print('inside the function')
    print(a)
    print(b)

bind_a_variable()
print('after  calling the function:',a, b)
# Out:
# before calling the function: None
# inside the function
# []
# [1]
# after  calling the function: [] 1

# %%
print(b)
# Out:
# 1

# %% [markdown]
# ## 1.5 return multiple values

# %%
def f():
    a = 5
    b = 6
    c = 7
    return {'a' : a, 'b' : b, 'c' : c}

call_f = f()
print(call_f)
# Out:
# {'a': 5, 'b': 6, 'c': 7}

# %% [markdown]
# ## 1.6 Lambda function

# %%
def apply_to_list(some_list, f):
    return [f(x) for x in some_list]

ints = [4, 0, 1, 5, 6]
apply_to_list(ints, lambda x: x * 2)
# Out:
# [8, 0, 2, 10, 12]
