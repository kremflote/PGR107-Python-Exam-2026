# %% [markdown]
# # Python Programming PGR107
# ## P9

# %% [markdown]
# ### P9.1 Numpy
#
# #### Create a numpy_a: 3x3 matrix with values ranging from 1 to 9 manually.
# #### Create a numpy_b: 3x3 matrix with values ranging from 10 to 18 by arange function.
# Then perform the following:
# - 9.1.1 Multiply "numpy_a" by element-by-element value to the power of 3. And stored to "numpy_c" variable.
# - 9.1.2 Change the "numpy_c" last 3 numbers to 100. And stored to "numpy_d" variable.
# - 9.1.3 Get the elements with the number 100 from the "numpy_d".And stored to "numpy_e" variable.
# - 9.1.4 Append one element 100 to "numpy_e". And stored to "numpy_f".
# - 9.1.5 Extract only even number in numpy_a using "slicing".And stored to "numpy_g" variable.
# - 9.1.6 Extract only odd number in numpy_b using "slicing".And stored to "numpy_h" variable.
# - 9.1.7 Add "numpy_f", "numpy_g" and "numpy_h".And stored to "numpy_i" variable.
# - 9.1.8 Change the "numpy_i" from int to float.(Hint! Use astype function.)
# - (Optional question) Use savetxt function and save 9.1.1 - 9.1.8 answers to a text file.
