# %% [markdown]
# # PGR107
# # P7
#
# we have two important tasks to complete.
# 1. You need to finish your group work for Mini-Project 1 and discuss how you will present your work if your group is selected to present. Make sure everyone understands their role in the presentation.
#
# 2. Review the provided link (https://www.udir.no/tall-og-forskning/statistikk/statistikk-videregaende-skole/karakterer-vgs/) and discuss in your groups on:
# 2.1 from vast information from the webpage, what can be learned from it.
# 2.2 Based on your discussion, define a clear problem for a Python project.
#
# While doing this, you must carefully consider the data you will use (based on the link and other relevant webpage, for example from SSB, the appropriate data structures, how to clearly define the problem, how to manage the project pipeline, propose a suitable solution, and decide how to divide and manage the work effectively within your group.
#
# NB: Pls get help from your TAs on these two tasks. Regarding task 1, you can discuss your submission and ask TA to make a note for your group (make sure each member of your group will be listed on a provided excel sheet). For task 2, you can discuss your ideas and problems defined and get some suggestion from TA.
