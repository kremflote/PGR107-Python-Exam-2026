# %%
# P6.1 tuple

# %%
## 1. understand tuple consists of tuples

tup = tuple(['foo', [1, 2], True])

# %%
tup[2] = False

# %%
tup[1].append(3)

# %%
tup
# Out:
# ('foo', [1, 2, 3], True)

# %%
new_tup = (4, None, 'foo') + (6, 0) + ('bar',)

print(new_tup)
# Out:
# (4, None, 'foo', 6, 0, 'bar')

# %%
('foo', 'bar') * 4
# Out:
# ('foo', 'bar', 'foo', 'bar', 'foo', 'bar', 'foo', 'bar')

# %%
# 2. Adding and removing elements

# change a value in a list
a_list = [2, 3, 7, None]

tup = ('foo', 'bar', 'baz')

b_list = list(tup)
print(b_list)


b_list[1] = 'peekaboo'
print(b_list)
# Out:
# ['foo', 'bar', 'baz']
# ['foo', 'peekaboo', 'baz']

# %%
b_list.append('red')
print(b_list)
# Out:
# ['foo', 'peekaboo', 'baz', 'red']

# %%
b_list.insert(1, 'red')
print(b_list)
# Out:
# ['foo', 'red', 'peekaboo', 'baz', 'red']

# %%
# pop

print(b_list.pop(2))

print(b_list)
# Out:
# peekaboo
# ['foo', 'red', 'baz', 'red']

# %%
# remove
print(b_list.remove('foo'))
print(b_list)
# Out:
# None
# ['red', 'baz', 'red']

# %%
'red' in b_list
# Out:
# True

# %%
## 3. concatenating
[4, None, 'foo'] + [7, 8, (2, 3)]
# Out:
# [4, None, 'foo', 7, 8, (2, 3)]

# %%
# extend
x = [4, None, 'foo']

x.extend([7, 8, (2, 3)])
print(x)
# Out:
# [4, None, 'foo', 7, 8, (2, 3)]

# %%
##  Slicing
seq = [7, 2, 3, 7, 5, 6, 0, 1]
seq[1:5]
seq[:5]
seq[3:]
seq = [0, 1, 2, 3, 4, 5]
# print(seq[-4:])

print(seq[::2])
#seq[:]
# Out:
# [0, 2, 4]
