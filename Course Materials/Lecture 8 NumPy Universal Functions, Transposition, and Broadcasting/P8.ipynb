# %% [markdown]
# # Python Programming PGR107

# %% [markdown]
# ### 8.1 Four arithmetic operations with Numpy
#
# - 8.1.1 Create two arrays A = [1, 2, 3, 4] and B = [5, 6, 7, 8].
#
# - 8.1.2 Compute the element-wise sum, difference, product, and quotient of A and B.

# %% [markdown]
# ### P8.2 Universal functions with Numpy
#
# Given the array C = [2, 7, 1, 8, 2, 8, 1, 8, 2, 8],
#
# - 8.2.1 Compute the sum of all elements in C using universal function.
#
# - 8.2.2 Find the product of all elements in C using universal function.
#
# - 8.2.3 Calculate the cumulative sum of elements in C using universal function.

# %% [markdown]
# ### P8.3 Broadcasting with 2D array
#
# - 8.3.1 Create a 2x3 matrix D = [[1, 2, 3], [4, 5, 6]].
#         - Create 1D array E = [1, 2, 1].
#         - Add the 1D array to each row of the 2x3 matrix.
#         - Output the product of multiplying 15 to the second element in D.
#
# - 8.3.2 Now create a 1D array F = [1, 2].
#         Reshape F so it can be added to each column of the 2x3 matrix D.

# %% [markdown]
# ### P8.4 Broadcasting with 3D array
#
# - 8.4.1 Create a 3D array G of shape (5,4,3) filled with random integers between 1 to 9.
#        - Created a 1D array H = [1,2,3]. Check difference from G to H.
#        - Create a copy of the 3D array G and name it I.
#        - Print(I); print(H)
#        - Output the product of I*H.  Then, in your own words, explain how the opearation is carried out.
