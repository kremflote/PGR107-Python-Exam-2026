# %% [markdown]
# # KUC
# # P6.1 instructions
# 1.	Find a group (2-4), work in groups - can be same group as the one you work for mini_project1
# 2.	Have group discussions on zip and unzip of two lists, understand zip and unzip (searching for documentation or other relevant materials)
# 3.	Understand lambda function individually, and then have group discussion.
# 4.	Write some code to explain your group understanding on zip, unzip, and lambda functions. This should be some new code that you can run and understand, not P6.2 and P6.3 code.
