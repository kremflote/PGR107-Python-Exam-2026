# %% [markdown]
# # Python Programming PGR107
#
#
#
# ## P9.2

# %% [markdown]
# ### P9.2
#
# We have created a dictionary 'city_info' as following.
# city_info = {
#     'State': ['Oslo', 'Bergen', 'Stavanger', 'Trondheim'],
#     'Population': [650000, 320000, 150000, 90000],
#     'Area': [450000, 240000, 310000, 360000]
# }
# Please perform the following steps.
#
# - 9.2.1 Convert the "city_info" dictionary into a pandas DataFrame.
# - 9.2.2 Select and print the "City" and "Population" columns.
# - 9.2.3 Select and print the data related to "Oslo" and "Stavanger".
# - 9.2.4 Find the cities where the population is smaller than 200 000
# - 9.2.5 Add a new column called "Population Density", which is calculated as (Population/Area).
# - 9.2.6 Find the state with the highest population density.
# - 9.2.7 Compute the average areas of all states, and the average population.
