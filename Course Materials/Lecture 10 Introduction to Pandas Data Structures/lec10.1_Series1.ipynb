# %% [markdown]
# # KUC, PGR107, Lec10.1

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1. Series, DataFrame, Index
# # 1.1 Series
# # 1.2 DataFrame
# # 1.3 Index

# %%
# 1.1.1
data = pd.Series([0.25, 0.5, 0.75, 1.0])

print(data) # arr, print(arr) [0.25 0.50   ]; arr
print(type(data))
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64
# <class 'pandas.Series'>

# %%
print(data[1])
# Out:
# 0.5

# %%
print(data.ndim)

print(data.shape)
# Out:
# 1
# (4,)

# %%
print(data.values)
# Out:
# [0.25 0.5  0.75 1.  ]

# %%
print(data.index)
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
print(data[1])
# Out:
# 0.5

# %%
print(data[1])
# Out:
# 0.5

# %%
print(data)
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64

# %%
print(data[1])
print(type(data[1]))
# Out:
# 0.5
# <class 'numpy.float64'>

# %%
print(data[1:1])
print(type(data[1:1]))
# Out:
# Series([], dtype: float64)
# <class 'pandas.Series'>

# %%
arr = np.array([0.25, 0.5, 0.75, 1.0])
print(arr)
# Out:
# [0.25 0.5  0.75 1.  ]

# %%
print(data)
print(type(data))
print(data[0])
print(type(data[0]))
print(arr)
print(type(arr))
# Out:
# 0    0.25
# 1    0.50
# 2    0.75
# 3    1.00
# dtype: float64
# <class 'pandas.Series'>
# 0.25
# <class 'numpy.float64'>
# [0.25 0.5  0.75 1.  ]
# <class 'numpy.ndarray'>

# %%
# 1.1.2
data = pd.Series([0.25, 0.5, 0.75, 1.0],
                 index=['a', 'b', 'c', 'd'])
print(data)
# Out:
# a    0.25
# b    0.50
# c    0.75
# d    1.00
# dtype: float64

# %%
print(data['b'])
print(data['b':'c'])
# Out:
# 0.5
# b    0.50
# c    0.75
# dtype: float64

# %%
# !don't be confused
data = pd.Series([0.25, 0.5, 0.75, 1.0],
                 index=[2, 5, 3, 7])

print(data[2])#0.75, or 0.25?
print(data[5])
print(data[3])
print(data[7])
# Out:
# 0.25
# 0.5
# 0.75
# 1.0

# %%
print(data[4])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/envs/PGR107Env/lib/python3.12/site-packages/pandas/core/indexes/base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2761, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2785, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 4
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 print(data[4])
#
# ...

# %%
print(data.iloc[2])
print(data.loc[2])
# Out:
# 0.75
# 0.25

# %%
data[5]
# Out:
# np.float64(0.5)

# %%
population_dict = {'California': 38332521,
                   'Texas': 26448193,
                   'New York': 20400000,
                   'Florida': 19552860,
                   'Illinois': 12882135,
                   'Oslo':1056180,
                   'Beijing':20896820}
population = pd.Series(population_dict)
population
# Out:
# California    38332521
# Texas         26448193
# New York      20400000
# Florida       19552860
# Illinois      12882135
# Oslo           1056180
# Beijing       20896820
# dtype: int64

# %%
print(population['Beijing'])
# Out:
# 20896820

# %%
# slicing!
population['Oslo':'Beijing']

# %%
# working or not?
# population['Oslo':-1]
# population.iloc[len(population)-1]
# Out:
# np.int64(20896820)

# %%
# 1.1.3. Construct a Series
pd.Series([2, 4, 6])
# Out:
# 0    2
# 1    4
# 2    6
# dtype: int64

# %%
pd.Series(5, index=[100, 200, 300])
# Out:
# 100    5
# 200    5
# 300    5
# dtype: int64

# %%
pd2= pd.Series({2:'a', 1:'b', 3:'c'})
print(pd2.values)
print(pd2.index)
# Out:
# <StringArray>
# ['a', 'b', 'c']
# Length: 3, dtype: str
# Index([2, 1, 3], dtype='int64')

# %%
# the index can be explicitly set if a different result is preferred
pd.Series({1:'a', 2:'b', 3:'c'}, index=[3, 2])
# Out:
# 3    c
# 2    b
# dtype: str
